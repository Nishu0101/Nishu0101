# %% [markdown]
# <a href="https://colab.research.google.com/github/Nishu0101/Nishu0101/blob/main/Python_day3_Titanic_dataAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#EDA : Exploratory Data Analysis
# EDA is a data analysis approach focused on investigating and summarizing the main characteristics of a data set, often through visualization and statistical methods.

# %%
#Pandas
#NumPy
#Matplotlib
#Seaborn

# %%
#NumPy
#pip install pandas

import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
t = sns.load_dataset('titanic')
t
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
t.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
t.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
t.dtypes
#all the string /text columns are shown as object data types
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
b= t[['sex', 'fare', 'deck']]        #for more than one column we use double square brackets
b
# Out:
#         sex     fare deck
# 0      male   7.2500  NaN
# 1    female  71.2833    C
# 2    female   7.9250  NaN
# 3    female  53.1000    C
# 4      male   8.0500  NaN
# ..      ...      ...  ...
# 886    male  13.0000  NaN
# 887  female  30.0000    B
# 888  female  23.4500  NaN
# 889    male  30.0000    C
# 890    male   7.7500  NaN
#
# [891 rows x 3 columns]

# %%
b= t['sex']      #for one column
b
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: sex, Length: 891, dtype: object

# %%
t.select_dtypes(include=['int64', 'category'])
# Out:
#      survived  pclass  sibsp  parch   class deck
# 0           0       3      1      0   Third  NaN
# 1           1       1      1      0   First    C
# 2           1       3      0      0   Third  NaN
# 3           1       1      1      0   First    C
# 4           0       3      0      0   Third  NaN
# ..        ...     ...    ...    ...     ...  ...
# 886         0       2      0      0  Second  NaN
# 887         1       1      0      0   First    B
# 888         0       3      1      2   Third  NaN
# 889         1       1      0      0   First    C
# 890         0       3      0      0   Third  NaN
#
# [891 rows x 6 columns]

# %%
t.loc[0]    # Single row
# Out:
# survived                 0
# pclass                   3
# sex                   male
# age                   22.0
# sibsp                    1
# parch                    0
# fare                  7.25
# embarked                 S
# class                Third
# who                    man
# adult_male            True
# deck                   NaN
# embark_town    Southampton
# alive                   no
# alone                False
# Name: 0, dtype: object

# %%
t.loc[[0,78,23,156]]       # Multi Row Indexing
# Out:
#      survived  pclass     sex    age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.00      1      0   7.2500        S   Third
# 78          1       2    male   0.83      0      2  29.0000        S  Second
# 23          1       1    male  28.00      0      0  35.5000        S   First
# 156         1       3  female  16.00      0      0   7.7333        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 78   child       False  NaN  Southampton   yes  False
# 23     man        True    A  Southampton   yes   True
# 156  woman       False  NaN   Queenstown   yes   True

# %%
t.head()        # Fetch first 5 records
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
t.tail()          # Fetch last 5 records
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
t.sample()            # Randomly fetches a single value
# Out:
#      survived  pclass     sex  age  sibsp  parch  fare embarked  class    who  \
# 573         1       3  female  NaN      0      0  7.75        Q  Third  woman
#
#      adult_male deck embark_town alive  alone
# 573       False  NaN  Queenstown   yes   True

# %%
t.sample(5)
# Out:
#      survived  pclass   sex   age  sibsp  parch   fare embarked   class  who  \
# 87          0       3  male   NaN      0      0   8.05        S   Third  man
# 589         0       3  male   NaN      0      0   8.05        S   Third  man
# 37          0       3  male  21.0      0      0   8.05        S   Third  man
# 288         1       2  male  42.0      0      0  13.00        S  Second  man
# 226         1       2  male  19.0      0      0  10.50        S  Second  man
#
#      adult_male deck  embark_town alive  alone
# 87         True  NaN  Southampton    no   True
# 589        True  NaN  Southampton    no   True
# 37         True  NaN  Southampton    no   True
# 288        True  NaN  Southampton   yes   True
# 226        True  NaN  Southampton   yes   True

# %%
t.loc[56:68:2]             # Slicing with step size 2
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 56         1       2  female  21.0      0      0  10.5000        S  Second
# 58         1       2  female   5.0      1      2  27.7500        S  Second
# 60         0       3    male  22.0      0      0   7.2292        C   Third
# 62         0       1    male  45.0      1      0  83.4750        S   First
# 64         0       1    male   NaN      0      0  27.7208        C   First
# 66         1       2  female  29.0      0      0  10.5000        S  Second
# 68         1       3  female  17.0      4      2   7.9250        S   Third
#
#       who  adult_male deck  embark_town alive  alone
# 56  woman       False  NaN  Southampton   yes   True
# 58  child       False  NaN  Southampton   yes  False
# 60    man        True  NaN    Cherbourg    no   True
# 62    man        True    C  Southampton    no  False
# 64    man        True  NaN    Cherbourg    no   True
# ...

# %%
####### DESCRIPTIVE STATISTICS IN PANDAS

t.age.min()
# Out:
# 0.42

# %%
t.age.max()
# Out:
# 80.0

# %%
t.age.mean()          #AVERAGE AGE
# Out:
# np.float64(29.69911764705882)

# %%
t.age.median()        #MIDDLEMOST ELEMENT WHEN DATA IS SORTED
# Out:
# 28.0

# %%
t.count()              #NUMBER OF NON-NULL OBSERVATION
# Out:
# survived       891
# pclass         891
# sex            891
# age            714
# sibsp          891
# parch          891
# fare           891
# embarked       889
# class          891
# who            891
# adult_male     891
# deck           203
# embark_town    889
# alive          891
# alone          891
# dtype: int64

# %%
len(t)
# Out:
# 891

# %%
len(t) - t.count()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
(len(t) - t.count())/len(t)*100
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
#len(t) - t.count()
t.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
t
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
### LABEL ENCODING: A process of coverting non numerical data into numeriacal data so as to perform numerical operations on it.


def embarkedToNum(data):
  d = {'S':1, 'C':2, 'Q':3, np.nan:np.nan}
  return d[data]

t.embarked.unique()

t['embaredkNum'] = t.embarked.apply(embarkedToNum)
t
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
t1= t.copy()

# %%
t.drop(columns = ['embark_town', 'deck', 'class', 'alive', 'alone'],
       inplace= True)
t
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked    who  \
# 0           0       3    male  22.0      1      0   7.2500        S    man
# 1           1       1  female  38.0      1      0  71.2833        C  woman
# 2           1       3  female  26.0      0      0   7.9250        S  woman
# 3           1       1  female  35.0      1      0  53.1000        S  woman
# 4           0       3    male  35.0      0      0   8.0500        S    man
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 886         0       2    male  27.0      0      0  13.0000        S    man
# 887         1       1  female  19.0      0      0  30.0000        S  woman
# 888         0       3  female   NaN      1      2  23.4500        S  woman
# 889         1       1    male  26.0      0      0  30.0000        C    man
# 890         0       3    male  32.0      0      0   7.7500        Q    man
#
#      adult_male  embaredkNum
# 0          True          1.0
# ...

# %%
t.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'who', 'adult_male', 'embaredkNum'],
#       dtype='object')

# %%
t.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# who              0
# adult_male       0
# embaredkNum      2
# dtype: int64

# %% [markdown]
# ### ***CORRELATION MATRIX***

# %%
tc = t.corr(numeric_only = True)
tc
# Out:
#              survived    pclass       age     sibsp     parch      fare  \
# survived     1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass      -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age         -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp       -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch        0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare         0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male  -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# embaredkNum  0.108669  0.043835  0.012186 -0.060606 -0.079320  0.063462
#
#              adult_male  embaredkNum
# survived      -0.557080     0.108669
# pclass         0.094035     0.043835
# age            0.280328     0.012186
# sibsp         -0.253586    -0.060606
# parch         -0.349943    -0.079320
# fare          -0.182024     0.063462
# adult_male     1.000000    -0.110351
# ...

# %%
t2 = t.copy()

# %%
sns.displot(x= t.age)

# %%
t2.age.median()
# Out:
# 28.0

# %%
t.age.fillna(t.age.mean(), inplace = True)
# Out:
# /tmp/ipython-input-1834366787.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   t.age.fillna(t.age.mean(), inplace = True)

# %%
sns.displot(x= t.age)

# %% [markdown]
# **FILTERING**

# %%
t.age.median()
# Out:
# 29.69911764705882

# %%
t2.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# who              0
# adult_male       0
# embaredkNum      2
# dtype: int64

# %%
t21 = t2[t2.pclass == 1]       # FILTERING VIA BOOLEAN ARRAY INDEXING
t21
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked    who  \
# 1           1       1  female  38.0      1      0  71.2833        C  woman
# 3           1       1  female  35.0      1      0  53.1000        S  woman
# 6           0       1    male  54.0      0      0  51.8625        S    man
# 11          1       1  female  58.0      0      0  26.5500        S  woman
# 23          1       1    male  28.0      0      0  35.5000        S    man
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  woman
# 872         0       1    male  33.0      0      0   5.0000        S    man
# 879         1       1  female  56.0      0      1  83.1583        C  woman
# 887         1       1  female  19.0      0      0  30.0000        S  woman
# 889         1       1    male  26.0      0      0  30.0000        C    man
#
#      adult_male  embaredkNum
# 1         False          2.0
# ...

# %%
t22 = t2[t2.pclass == 2]
t22
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked    who  \
# 9           1       2  female  14.0      1      0  30.0708        C  child
# 15          1       2  female  55.0      0      0  16.0000        S  woman
# 17          1       2    male   NaN      0      0  13.0000        S    man
# 20          0       2    male  35.0      0      0  26.0000        S    man
# 21          1       2    male  34.0      0      0  13.0000        S    man
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 866         1       2  female  27.0      1      0  13.8583        C  woman
# 874         1       2  female  28.0      1      0  24.0000        C  woman
# 880         1       2  female  25.0      0      1  26.0000        S  woman
# 883         0       2    male  28.0      0      0  10.5000        S    man
# 886         0       2    male  27.0      0      0  13.0000        S    man
#
#      adult_male  embaredkNum
# 9         False          2.0
# ...

# %%
t23 = t2[t2.pclass == 3]
t23
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked    who  \
# 0           0       3    male  22.0      1      0   7.2500        S    man
# 2           1       3  female  26.0      0      0   7.9250        S  woman
# 4           0       3    male  35.0      0      0   8.0500        S    man
# 5           0       3    male   NaN      0      0   8.4583        Q    man
# 7           0       3    male   2.0      3      1  21.0750        S  child
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 882         0       3  female  22.0      0      0  10.5167        S  woman
# 884         0       3    male  25.0      0      0   7.0500        S    man
# 885         0       3  female  39.0      0      5  29.1250        Q  woman
# 888         0       3  female   NaN      1      2  23.4500        S  woman
# 890         0       3    male  32.0      0      0   7.7500        Q    man
#
#      adult_male  embaredkNum
# 0          True          1.0
# ...

# %%
t21.age.fillna(t21.age.mean(), inplace = True)
# Out:
# /tmp/ipython-input-1493078070.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   t21.age.fillna(t21.age.mean(), inplace = True)
# /tmp/ipython-input-1493078070.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t21.age.fillna(t21.age.mean(), inplace = True)

# %%
t22.age.fillna(t22.age.mean(), inplace = True)
# Out:
# /tmp/ipython-input-245498425.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   t22.age.fillna(t22.age.mean(), inplace = True)
# /tmp/ipython-input-245498425.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t22.age.fillna(t22.age.mean(), inplace = True)

# %%
t23.age.fillna(t23.age.mean(), inplace = True)
# Out:
# /tmp/ipython-input-2671054600.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   t23.age.fillna(t23.age.mean(), inplace = True)
# /tmp/ipython-input-2671054600.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t23.age.fillna(t23.age.mean(), inplace = True)

# %%
sns.displot(x= t21.age)

# %%
sns.displot(x= t22.age)

# %%
sns.displot(x= t23.age)

# %%
t4 = pd.concat([t21, t22, t23])
t4
# Out:
#      survived  pclass     sex       age  sibsp  parch     fare embarked  \
# 1           1       1  female  38.00000      1      0  71.2833        C
# 3           1       1  female  35.00000      1      0  53.1000        S
# 6           0       1    male  54.00000      0      0  51.8625        S
# 11          1       1  female  58.00000      0      0  26.5500        S
# 23          1       1    male  28.00000      0      0  35.5000        S
# ..        ...     ...     ...       ...    ...    ...      ...      ...
# 882         0       3  female  22.00000      0      0  10.5167        S
# 884         0       3    male  25.00000      0      0   7.0500        S
# 885         0       3  female  39.00000      0      5  29.1250        Q
# 888         0       3  female  25.14062      1      2  23.4500        S
# 890         0       3    male  32.00000      0      0   7.7500        Q
#
#        who  adult_male  embaredkNum
# 1    woman       False          2.0
# ...

# %%
t4.sort_index(inplace = True)
t4
# Out:
#      survived  pclass     sex       age  sibsp  parch     fare embarked  \
# 0           0       3    male  22.00000      1      0   7.2500        S
# 1           1       1  female  38.00000      1      0  71.2833        C
# 2           1       3  female  26.00000      0      0   7.9250        S
# 3           1       1  female  35.00000      1      0  53.1000        S
# 4           0       3    male  35.00000      0      0   8.0500        S
# ..        ...     ...     ...       ...    ...    ...      ...      ...
# 886         0       2    male  27.00000      0      0  13.0000        S
# 887         1       1  female  19.00000      0      0  30.0000        S
# 888         0       3  female  25.14062      1      2  23.4500        S
# 889         1       1    male  26.00000      0      0  30.0000        C
# 890         0       3    male  32.00000      0      0   7.7500        Q
#
#        who  adult_male  embaredkNum
# 0      man        True          1.0
# ...

# %%
sns.displot(x= t4.age)

# %%
def sexToNum(data):
  d = {'male':1, 'female':2}
  return d[data]

t4.sex.unique()

t4['sexNum'] = t4.sex.apply(sexToNum)
t4
# Out:
#      survived  pclass     sex       age  sibsp  parch     fare embarked  \
# 0           0       3    male  22.00000      1      0   7.2500        S
# 1           1       1  female  38.00000      1      0  71.2833        C
# 2           1       3  female  26.00000      0      0   7.9250        S
# 3           1       1  female  35.00000      1      0  53.1000        S
# 4           0       3    male  35.00000      0      0   8.0500        S
# ..        ...     ...     ...       ...    ...    ...      ...      ...
# 886         0       2    male  27.00000      0      0  13.0000        S
# 887         1       1  female  19.00000      0      0  30.0000        S
# 888         0       3  female  25.14062      1      2  23.4500        S
# 889         1       1    male  26.00000      0      0  30.0000        C
# 890         0       3    male  32.00000      0      0   7.7500        Q
#
#        who  adult_male  embaredkNum  sexNum
# 0      man        True          1.0       1
# ...

# %%
t4c = t4.corr(numeric_only = True)
t4c
# Out:
#              survived    pclass       age     sibsp     parch      fare  \
# survived     1.000000 -0.338481 -0.050504 -0.035322  0.081629  0.257307
# pclass      -0.338481  1.000000 -0.403858  0.083081  0.018443 -0.549500
# age         -0.050504 -0.403858  1.000000 -0.243452 -0.175799  0.120886
# sibsp       -0.035322  0.083081 -0.243452  1.000000  0.414838  0.159651
# parch        0.081629  0.018443 -0.175799  0.414838  1.000000  0.216225
# fare         0.257307 -0.549500  0.120886  0.159651  0.216225  1.000000
# adult_male  -0.557080  0.094035  0.244111 -0.253586 -0.349943 -0.182024
# embaredkNum  0.108669  0.043835 -0.034432 -0.060606 -0.079320  0.063462
# sexNum       0.543351 -0.131900 -0.080464  0.114631  0.245489  0.182333
#
#              adult_male  embaredkNum    sexNum
# survived      -0.557080     0.108669  0.543351
# pclass         0.094035     0.043835 -0.131900
# age            0.244111    -0.034432 -0.080464
# sibsp         -0.253586    -0.060606  0.114631
# ...

# %%
t2.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# who              0
# adult_male       0
# embaredkNum      2
# dtype: int64

# %%
def sexToNum(data):
  d = {'male':1, 'female':2}
  return d[data]

t2.sex.unique()

t2['sexNum'] = t2.sex.apply(sexToNum)
t2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked    who  \
# 0           0       3    male  22.0      1      0   7.2500        S    man
# 1           1       1  female  38.0      1      0  71.2833        C  woman
# 2           1       3  female  26.0      0      0   7.9250        S  woman
# 3           1       1  female  35.0      1      0  53.1000        S  woman
# 4           0       3    male  35.0      0      0   8.0500        S    man
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 886         0       2    male  27.0      0      0  13.0000        S    man
# 887         1       1  female  19.0      0      0  30.0000        S  woman
# 888         0       3  female   NaN      1      2  23.4500        S  woman
# 889         1       1    male  26.0      0      0  30.0000        C    man
# 890         0       3    male  32.0      0      0   7.7500        Q    man
#
#      adult_male  embaredkNum  sexNum
# ...

# %%
t5=t2.copy()

# %%
tc = t2.corr(numeric_only = True)
tc
# Out:
#              survived    pclass       age     sibsp     parch      fare  \
# survived     1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass      -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age         -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp       -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch        0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare         0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male  -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# embaredkNum  0.108669  0.043835  0.012186 -0.060606 -0.079320  0.063462
# sexNum       0.543351 -0.131900 -0.093254  0.114631  0.245489  0.182333
#
#              adult_male  embaredkNum    sexNum
# survived      -0.557080     0.108669  0.543351
# pclass         0.094035     0.043835 -0.131900
# age            0.280328     0.012186 -0.093254
# sibsp         -0.253586    -0.060606  0.114631
# ...

# %%
t51m = t5[(t5.pclass ==1) & (t5.sex == 'male')]
t52m = t5[(t5.pclass ==2) & (t5.sex == 'male')]
t53m = t5[(t5.pclass ==3) & (t5.sex == 'male')]
t54m = t5[(t5.pclass ==1) & (t5.sex == 'female')]
t55m = t5[(t5.pclass ==2) & (t5.sex == 'female')]
t56m = t5[(t5.pclass ==3) & (t5.sex == 'female')]

# %%
t51m.age.fillna(t51m.age.mean(), inplace = True)
t52m.age.fillna(t52m.age.mean(), inplace = True)
t53m.age.fillna(t53m.age.mean(), inplace = True)
t54m.age.fillna(t54m.age.mean(), inplace = True)
t55m.age.fillna(t55m.age.mean(), inplace = True)
t56m.age.fillna(t56m.age.mean(), inplace = True)
# Out:
# /tmp/ipython-input-3872695999.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   t51m.age.fillna(t51m.age.mean(), inplace = True)
# /tmp/ipython-input-3872695999.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t51m.age.fillna(t51m.age.mean(), inplace = True)
# ...

# %%
sns.displot(x= t51m.age)

# %%
sns.displot(x= t52m.age)

# %%
sns.displot(x= t53m.age)

# %%
sns.displot(x= t54m.age)

# %%
sns.displot(x= t55m.age)

# %%
sns.displot(x= t56m.age)

# %%
t5m = pd.concat([t51m, t52m, t53m, t54m, t55m, t56m])
t5m
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked    who  \
# 6           0       1    male  54.00      0      0   51.8625        S    man
# 23          1       1    male  28.00      0      0   35.5000        S    man
# 27          0       1    male  19.00      3      2  263.0000        S    man
# 30          0       1    male  40.00      0      0   27.7208        C    man
# 34          0       1    male  28.00      1      0   82.1708        C    man
# ..        ...     ...     ...    ...    ...    ...       ...      ...    ...
# 863         0       3  female  21.75      8      2   69.5500        S  woman
# 875         1       3  female  15.00      0      0    7.2250        C  child
# 882         0       3  female  22.00      0      0   10.5167        S  woman
# 885         0       3  female  39.00      0      5   29.1250        Q  woman
# 888         0       3  female  21.75      1      2   23.4500        S  woman
#
#      adult_male  embaredkNum  sexNum
# ...

# %%
t5m.sort_index(inplace = True)
t5m
# Out:
#      survived  pclass     sex    age  sibsp  parch     fare embarked    who  \
# 0           0       3    male  22.00      1      0   7.2500        S    man
# 1           1       1  female  38.00      1      0  71.2833        C  woman
# 2           1       3  female  26.00      0      0   7.9250        S  woman
# 3           1       1  female  35.00      1      0  53.1000        S  woman
# 4           0       3    male  35.00      0      0   8.0500        S    man
# ..        ...     ...     ...    ...    ...    ...      ...      ...    ...
# 886         0       2    male  27.00      0      0  13.0000        S    man
# 887         1       1  female  19.00      0      0  30.0000        S  woman
# 888         0       3  female  21.75      1      2  23.4500        S  woman
# 889         1       1    male  26.00      0      0  30.0000        C    man
# 890         0       3    male  32.00      0      0   7.7500        Q    man
#
#      adult_male  embaredkNum  sexNum
# ...

# %%
sns.displot(x= t5m.age)

# %%
tem= t2[t2.embarked.isnull()]
tem
# Out:
#      survived  pclass     sex   age  sibsp  parch  fare embarked    who  \
# 61          1       1  female  38.0      0      0  80.0      NaN  woman
# 829         1       1  female  62.0      0      0  80.0      NaN  woman
#
#      adult_male  embaredkNum  sexNum
# 61        False          NaN       2
# 829       False          NaN       2

# %%
tem.index
# Out:
# Index([61, 829], dtype='int64')

# %%
print(tem.index)
# Out:
# Index([61, 829], dtype='int64')

# %%
t2.embarked.value_counts()
# Out:
# embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
round(t2.embarked.value_counts()/len(t2)*100,1)
# Out:
# embarked
# S    72.3
# C    18.9
# Q     8.6
# Name: count, dtype: float64

# %%
### GROUPBY OPERATION IN PANDAS

# %%
t2.age.mean()
# Out:
# np.float64(29.69911764705882)

# %%
t2[t2.sex == 'male'].age.mean()
# Out:
# np.float64(30.72664459161148)

# %%
t2[t2.sex == 'female'].age.mean()
# Out:
# np.float64(27.915708812260537)

# %%
t2.groupby('sex').age.mean()
# Out:
# sex
# female    27.915709
# male      30.726645
# Name: age, dtype: float64

# %%
t2.groupby('pclass').embarked.value_counts()
# Out:
# pclass  embarked
# 1       S           127
#         C            85
#         Q             2
# 2       S           164
#         C            17
#         Q             3
# 3       S           353
#         Q            72
#         C            66
# Name: count, dtype: int64

# %%
t2.groupby(['pclass', 'sex']).embarked.value_counts()
# Out:
# pclass  sex     embarked
# 1       female  S            48
#                 C            43
#                 Q             1
#         male    S            79
#                 C            42
#                 Q             1
# 2       female  S            67
#                 C             7
#                 Q             2
#         male    S            97
#                 C            10
#                 Q             1
# 3       female  S            88
#                 Q            33
#                 C            23
#         male    S           265
#                 C            43
#                 Q            39
# Name: count, dtype: int64

# %%
t2.describe()       #numeric value true
# Out:
#          survived      pclass         age       sibsp       parch        fare  \
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200
#
#        embaredkNum      sexNum
# count   889.000000  891.000000
# mean      1.362205    1.352413
# std       0.636157    0.477990
# min       1.000000    1.000000
# 25%       1.000000    1.000000
# 50%       1.000000    1.000000
# 75%       2.000000    2.000000
# ...

# %%
t2.age.median()
# Out:
# 28.0

# %%
sns.boxplot(x= t2.age)        #####  HANDLING OUTLIERS IN PANDAS
# Out:
# <Axes: xlabel='age'>

# %%
t2.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare  \
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200
#
#        embaredkNum      sexNum
# count   889.000000  891.000000
# mean      1.362205    1.352413
# std       0.636157    0.477990
# min       1.000000    1.000000
# 25%       1.000000    1.000000
# 50%       1.000000    1.000000
# 75%       2.000000    2.000000
# ...

# %%
t2.fare.median()
# Out:
# 14.4542

# %%
  #FARE
  #min=0
  #Q1 =7.91
  #Q2 =14.45
  #Q3 =31
  #max =512.329


  #IQR =23.09
  #IQRmax = Q3 + 1.5*IQR = 31 + 1.5*23.09 = 65.635
  #IQRmin = Q1 - 1.5*IQR = 7.91 - 1.5*23.09 = -26.725


  #lower_whisker =

# %%
sns.boxplot(x= t2.fare)
# Out:
# <Axes: xlabel='fare'>

# %%
sns.boxplot?

# %%
sns.boxplot()
# Out:
# <Axes: >

# %%
#outlier Removal
t7 = t2[t2.fare < 65.635]
t7
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked    who  \
# 0           0       3    male  22.0      1      0   7.2500        S    man
# 2           1       3  female  26.0      0      0   7.9250        S  woman
# 3           1       1  female  35.0      1      0  53.1000        S  woman
# 4           0       3    male  35.0      0      0   8.0500        S    man
# 5           0       3    male   NaN      0      0   8.4583        Q    man
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 886         0       2    male  27.0      0      0  13.0000        S    man
# 887         1       1  female  19.0      0      0  30.0000        S  woman
# 888         0       3  female   NaN      1      2  23.4500        S  woman
# 889         1       1    male  26.0      0      0  30.0000        C    man
# 890         0       3    male  32.0      0      0   7.7500        Q    man
#
#      adult_male  embaredkNum  sexNum
# ...

# %%
t2.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare  \
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200
#
#        embaredkNum      sexNum
# count   889.000000  891.000000
# mean      1.362205    1.352413
# std       0.636157    0.477990
# min       1.000000    1.000000
# 25%       1.000000    1.000000
# 50%       1.000000    1.000000
# 75%       2.000000    2.000000
# ...

# %%
t2.age.mean()
# Out:
# np.float64(29.69911764705882)

# %%
t2.age.median()
# Out:
# 28.0

# %%
t2.age.min()
# Out:
# 0.42

# %%
t2.age.max()
# Out:
# 80.0

# %%
t2.age.sum()
# Out:
# np.float64(21205.17)

# %%
t2.age.var()
# Out:
# 211.0191247463081

# %%
t2.age.std()
# Out:
# 14.526497332334044

# %%
t2.age.prod()
# Out:
# /usr/local/lib/python3.12/dist-packages/numpy/_core/_methods.py:56: RuntimeWarning: overflow encountered in reduce
#   return umr_prod(a, axis, dtype, out, keepdims, initial, where)
# np.float64(inf)

# %%
t2.age.cumsum()     #CUMULATIVE_SUM / RUNNING TOTAL
# Out:
# 0         22.00
# 1         60.00
# 2         86.00
# 3        121.00
# 4        156.00
#          ...
# 886    21128.17
# 887    21147.17
# 888         NaN
# 889    21173.17
# 890    21205.17
# Name: age, Length: 891, dtype: float64

# %%
t2.age.cumprod()    #CUMULATIVE_PRODUCT
# Out:
# /usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# 0            22.0
# 1           836.0
# 2         21736.0
# 3        760760.0
# 4      26626600.0
#           ...
# 886           inf
# 887           inf
# 888           NaN
# 889           inf
# 890           inf
# Name: age, Length: 891, dtype: float64

# %%
##   GROUPBY OPERATION IN PANDAS

t2.age.mean()
# Out:
# np.float64(29.69911764705882)

# %%
t2.groupby('pclass').age.mean()
# Out:
# pclass
# 1    38.233441
# 2    29.877630
# 3    25.140620
# Name: age, dtype: float64

# %%
#####   AGGREGATE FUNCTION
t2.groupby('pclass').age.agg([ 'min', 'mean', 'max']).add_suffix('_age')
# Out:
#         min_age   mean_age  max_age
# pclass
# 1          0.92  38.233441     80.0
# 2          0.67  29.877630     70.0
# 3          0.42  25.140620     74.0

# %%
t2.groupby('pclass').age.describe()
# Out:
#         count       mean        std   min   25%   50%   75%   max
# pclass
# 1       186.0  38.233441  14.802856  0.92  27.0  37.0  49.0  80.0
# 2       173.0  29.877630  14.001077  0.67  23.0  29.0  36.0  70.0
# 3       355.0  25.140620  12.495398  0.42  18.0  24.0  32.0  74.0

# %%
sns.boxplot(x= t2.age)
# Out:
# <Axes: xlabel='age'>

# %%
sns.boxplot(x= t2.age, hue= t2.pclass)
# Out:
# <Axes: xlabel='age'>

# %%
t2.pclass.value_counts()
# Out:
# pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
sns.countplot(x= t2.pclass)
# Out:
# <Axes: xlabel='pclass', ylabel='count'>

# %%
t2.groupby('sex').pclass.value_counts()
# Out:
# sex     pclass
# female  3         144
#         1          94
#         2          76
# male    3         347
#         1         122
#         2         108
# Name: count, dtype: int64

# %%
sns.countplot(x= t2.pclass, hue= t2.sex)
# Out:
# <Axes: xlabel='pclass', ylabel='count'>

# %%
sns.countplot(x = t2.sex, hue = t2.pclass)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
#####   CONCATENATION DATAFRAMES IN PANDAS


t2.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'who', 'adult_male', 'embaredkNum', 'sexNum'],
#       dtype='object')

# %%
n1 = t2[['age', 'fare', 'who', 'survived']].loc[55:59]
n1
# Out:
#      age     fare    who  survived
# 55   NaN  35.5000    man         1
# 56  21.0  10.5000  woman         1
# 57  28.5   7.2292    man         0
# 58   5.0  27.7500  child         1
# 59  11.0  46.9000  child         0

# %%
n2 = t2.drop(columns = ['adult_male', 'fare']).loc[100:103]
n2
# Out:
#      survived  pclass     sex   age  sibsp  parch embarked    who  \
# 100         0       3  female  28.0      0      0        S  woman
# 101         0       3    male   NaN      0      0        S    man
# 102         0       1    male  21.0      0      1        S    man
# 103         0       3    male  33.0      0      0        S    man
#
#      embaredkNum  sexNum
# 100          1.0       2
# 101          1.0       1
# 102          1.0       1
# 103          1.0       1

# %%
pd.concat([n2, n1])
# Out:
#      survived  pclass     sex   age  sibsp  parch embarked    who  \
# 100         0     3.0  female  28.0    0.0    0.0        S  woman
# 101         0     3.0    male   NaN    0.0    0.0        S    man
# 102         0     1.0    male  21.0    0.0    1.0        S    man
# 103         0     3.0    male  33.0    0.0    0.0        S    man
# 55          1     NaN     NaN   NaN    NaN    NaN      NaN    man
# 56          1     NaN     NaN  21.0    NaN    NaN      NaN  woman
# 57          0     NaN     NaN  28.5    NaN    NaN      NaN    man
# 58          1     NaN     NaN   5.0    NaN    NaN      NaN  child
# 59          0     NaN     NaN  11.0    NaN    NaN      NaN  child
#
#      embaredkNum  sexNum     fare
# 100          1.0     2.0      NaN
# 101          1.0     1.0      NaN
# 102          1.0     1.0      NaN
# 103          1.0     1.0      NaN
# 55           NaN     NaN  35.5000
# 56           NaN     NaN  10.5000
# 57           NaN     NaN   7.2292
# ...

# %%
pd.concat([n1, n2])
# Out:
#       age     fare    who  survived  pclass     sex  sibsp  parch embarked  \
# 55    NaN  35.5000    man         1     NaN     NaN    NaN    NaN      NaN
# 56   21.0  10.5000  woman         1     NaN     NaN    NaN    NaN      NaN
# 57   28.5   7.2292    man         0     NaN     NaN    NaN    NaN      NaN
# 58    5.0  27.7500  child         1     NaN     NaN    NaN    NaN      NaN
# 59   11.0  46.9000  child         0     NaN     NaN    NaN    NaN      NaN
# 100  28.0      NaN  woman         0     3.0  female    0.0    0.0        S
# 101   NaN      NaN    man         0     3.0    male    0.0    0.0        S
# 102  21.0      NaN    man         0     1.0    male    0.0    1.0        S
# 103  33.0      NaN    man         0     3.0    male    0.0    0.0        S
#
#      embaredkNum  sexNum
# 55           NaN     NaN
# 56           NaN     NaN
# 57           NaN     NaN
# 58           NaN     NaN
# 59           NaN     NaN
# 100          1.0     2.0
# 101          1.0     1.0
# ...

# %%
n3=t2[['age', 'fare']].loc[85:89]
n4=t2[['sex', 'survived']].loc[85:90]

# %%
n3
# Out:
#      age     fare
# 85  33.0   15.850
# 86  16.0   34.375
# 87   NaN    8.050
# 88  23.0  263.000
# 89  24.0    8.050

# %%
n4
# Out:
#        sex  survived
# 85  female         1
# 86    male         0
# 87    male         0
# 88  female         1
# 89    male         0
# 90    male         0

# %%
pd.concat([n3, n4], axis = 1)
# Out:
#      age     fare     sex  survived
# 85  33.0   15.850  female         1
# 86  16.0   34.375    male         0
# 87   NaN    8.050    male         0
# 88  23.0  263.000  female         1
# 89  24.0    8.050    male         0
# 90   NaN      NaN    male         0

# %%
pd.concat([n4, n3], axis = 0)
# Out:
#        sex  survived   age     fare
# 85  female       1.0   NaN      NaN
# 86    male       0.0   NaN      NaN
# 87    male       0.0   NaN      NaN
# 88  female       1.0   NaN      NaN
# 89    male       0.0   NaN      NaN
# 90    male       0.0   NaN      NaN
# 85     NaN       NaN  33.0   15.850
# 86     NaN       NaN  16.0   34.375
# 87     NaN       NaN   NaN    8.050
# 88     NaN       NaN  23.0  263.000
# 89     NaN       NaN  24.0    8.050

# %%
#####   MERGING DATA IN PANDAS


a=pd.DataFrame({'id' :[1,2,3,4,5],
                'Name':['Alax', 'Amy', 'Allen', 'Alice', 'Ayoung'],
                'Sub_id': [1,2,3,4,5]})
b = pd.DataFrame({'id' :[1,2,3,4,5],
                'Name':['Betty', 'Brian', 'Bryce', 'Billy', 'Bran'],
                'Sub_id': [1,2,3,4,5]})

a
# Out:
#    id    Name  Sub_id
# 0   1    Alax       1
# 1   2     Amy       2
# 2   3   Allen       3
# 3   4   Alice       4
# 4   5  Ayoung       5

# %%
pd.merge(a, b, on = 'id')          #### how = inner(intersection)
# Out:
#    id  Name_x  Sub_id_x Name_y  Sub_id_y
# 0   1    Alax         1  Betty         1
# 1   2     Amy         2  Brian         2
# 2   3   Allen         3  Bryce         3
# 3   4   Alice         4  Billy         4
# 4   5  Ayoung         5   Bran         5

# %%
pd.merge(a,b, on='Name')
# Out:
# Empty DataFrame
# Columns: [id_x, Name, Sub_id_x, id_y, Sub_id_y]
# Index: []

# %%
pd.merge(a,b, on='Sub_id')
# Out:
#    id_x  Name_x  Sub_id  id_y Name_y
# 0     1    Alax       1     1  Betty
# 1     2     Amy       2     2  Brian
# 2     3   Allen       3     3  Bryce
# 3     4   Alice       4     4  Billy
# 4     5  Ayoung       5     5   Bran

# %%
pd.merge(a,b, on='id', how = 'outer')     ###UNION
# Out:
#    id  Name_x  Sub_id_x Name_y  Sub_id_y
# 0   1    Alax         1  Betty         1
# 1   2     Amy         2  Brian         2
# 2   3   Allen         3  Bryce         3
# 3   4   Alice         4  Billy         4
# 4   5  Ayoung         5   Bran         5

# %%
pd.merge(a,b, on='Name', how = 'outer')
# Out:
#    id_x    Name  Sub_id_x  id_y  Sub_id_y
# 0   1.0    Alax       1.0   NaN       NaN
# 1   4.0   Alice       4.0   NaN       NaN
# 2   3.0   Allen       3.0   NaN       NaN
# 3   2.0     Amy       2.0   NaN       NaN
# 4   5.0  Ayoung       5.0   NaN       NaN
# 5   NaN   Betty       NaN   1.0       1.0
# 6   NaN   Billy       NaN   4.0       4.0
# 7   NaN    Bran       NaN   5.0       5.0
# 8   NaN   Brian       NaN   2.0       2.0
# 9   NaN   Bryce       NaN   3.0       3.0

# %%
pd.merge(a,b, on='Sub_id', how = 'outer')
# Out:
#    id_x  Name_x  Sub_id  id_y Name_y
# 0     1    Alax       1     1  Betty
# 1     2     Amy       2     2  Brian
# 2     3   Allen       3     3  Bryce
# 3     4   Alice       4     4  Billy
# 4     5  Ayoung       5     5   Bran

# %%
pd.merge(a,b, on='Sub_id', how = 'left')
# Out:
#    id_x  Name_x  Sub_id  id_y Name_y
# 0     1    Alax       1     1  Betty
# 1     2     Amy       2     2  Brian
# 2     3   Allen       3     3  Bryce
# 3     4   Alice       4     4  Billy
# 4     5  Ayoung       5     5   Bran

# %%
pd.merge(a,b, on='Sub_id', how = 'right')
# Out:
#    id_x  Name_x  Sub_id  id_y Name_y
# 0     1    Alax       1     1  Betty
# 1     2     Amy       2     2  Brian
# 2     3   Allen       3     3  Bryce
# 3     4   Alice       4     4  Billy
# 4     5  Ayoung       5     5   Bran

# %%
pd.merge(a,b, on='id', how = 'left')
# Out:
#    id  Name_x  Sub_id_x Name_y  Sub_id_y
# 0   1    Alax         1  Betty         1
# 1   2     Amy         2  Brian         2
# 2   3   Allen         3  Bryce         3
# 3   4   Alice         4  Billy         4
# 4   5  Ayoung         5   Bran         5

# %%
pd.merge(a,b, on=['id','Sub_id'], how = 'inner')
# Out:
#    id  Name_x  Sub_id Name_y
# 0   1    Alax       1  Betty
# 1   2     Amy       2  Brian
# 2   3   Allen       3  Bryce
# 3   4   Alice       4  Billy
# 4   5  Ayoung       5   Bran

# %%
pd.merge(a,b, on='Sub_id', how = 'inner')
# Out:
#    id_x  Name_x  Sub_id  id_y Name_y
# 0     1    Alax       1     1  Betty
# 1     2     Amy       2     2  Brian
# 2     3   Allen       3     3  Bryce
# 3     4   Alice       4     4  Billy
# 4     5  Ayoung       5     5   Bran

# %%
su = pd.merge(a,b, on='Sub_id', how = 'outer')
su
# Out:
#    id_x  Name_x  Sub_id  id_y Name_y
# 0     1    Alax       1     1  Betty
# 1     2     Amy       2     2  Brian
# 2     3   Allen       3     3  Bryce
# 3     4   Alice       4     4  Billy
# 4     5  Ayoung       5     5   Bran

# %%
su=pd.merge(a,b, on='Sub_id', how = 'outer')
su[su.isnull().any(axis = 1)]
# Out:
# Empty DataFrame
# Columns: [id_x, Name_x, Sub_id, id_y, Name_y]
# Index: []

# %%
su
# Out:
#    id_x  Name_x  Sub_id  id_y Name_y
# 0     1    Alax       1     1  Betty
# 1     2     Amy       2     2  Brian
# 2     3   Allen       3     3  Bryce
# 3     4   Alice       4     4  Billy
# 4     5  Ayoung       5     5   Bran

# %%
t2.isnull()
# Out:
#      survived  pclass    sex    age  sibsp  parch   fare  embarked    who  \
# 0       False   False  False  False  False  False  False     False  False
# 1       False   False  False  False  False  False  False     False  False
# 2       False   False  False  False  False  False  False     False  False
# 3       False   False  False  False  False  False  False     False  False
# 4       False   False  False  False  False  False  False     False  False
# ..        ...     ...    ...    ...    ...    ...    ...       ...    ...
# 886     False   False  False  False  False  False  False     False  False
# 887     False   False  False  False  False  False  False     False  False
# 888     False   False  False   True  False  False  False     False  False
# 889     False   False  False  False  False  False  False     False  False
# 890     False   False  False  False  False  False  False     False  False
#
#      adult_male  embaredkNum  sexNum
# 0         False        False   False
# ...
