# %% [markdown]
# <a href="https://colab.research.google.com/github/Nishu0101/Nishu0101/blob/main/Day8_Maternal_Health_Risk.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/Maternal Health Risk Data Set.csv')

# %%
df
# Out:
#       Age  SystolicBP  DiastolicBP    BS  BodyTemp  HeartRate  RiskLevel
# 0      25         130           80  15.0      98.0         86  high risk
# 1      35         140           90  13.0      98.0         70  high risk
# 2      29          90           70   8.0     100.0         80  high risk
# 3      30         140           85   7.0      98.0         70  high risk
# 4      35         120           60   6.1      98.0         76   low risk
# ...   ...         ...          ...   ...       ...        ...        ...
# 1009   22         120           60  15.0      98.0         80  high risk
# 1010   55         120           90  18.0      98.0         60  high risk
# 1011   35          85           60  19.0      98.0         86  high risk
# 1012   43         120           90  18.0      98.0         70  high risk
# 1013   32         120           65   6.0     101.0         76   mid risk
#
# [1014 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1014 entries, 0 to 1013
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Age          1014 non-null   int64
#  1   SystolicBP   1014 non-null   int64
#  2   DiastolicBP  1014 non-null   int64
#  3   BS           1014 non-null   float64
#  4   BodyTemp     1014 non-null   float64
#  5   HeartRate    1014 non-null   int64
#  6   RiskLevel    1014 non-null   object
# dtypes: float64(2), int64(4), object(1)
# memory usage: 55.6+ KB

# %%
df.head()
# Out:
#    Age  SystolicBP  DiastolicBP    BS  BodyTemp  HeartRate  RiskLevel
# 0   25         130           80  15.0      98.0         86  high risk
# 1   35         140           90  13.0      98.0         70  high risk
# 2   29          90           70   8.0     100.0         80  high risk
# 3   30         140           85   7.0      98.0         70  high risk
# 4   35         120           60   6.1      98.0         76   low risk

# %%
df.describe()
# Out:
#                Age   SystolicBP  DiastolicBP           BS     BodyTemp  \
# count  1014.000000  1014.000000  1014.000000  1014.000000  1014.000000
# mean     29.871795   113.198225    76.460552     8.725986    98.665089
# std      13.474386    18.403913    13.885796     3.293532     1.371384
# min      10.000000    70.000000    49.000000     6.000000    98.000000
# 25%      19.000000   100.000000    65.000000     6.900000    98.000000
# 50%      26.000000   120.000000    80.000000     7.500000    98.000000
# 75%      39.000000   120.000000    90.000000     8.000000    98.000000
# max      70.000000   160.000000   100.000000    19.000000   103.000000
#
#          HeartRate
# count  1014.000000
# mean     74.301775
# std       8.088702
# min       7.000000
# 25%      70.000000
# 50%      76.000000
# 75%      80.000000
# max      90.000000

# %%
df.head()
# Out:
#    Age  SystolicBP  DiastolicBP    BS  BodyTemp  HeartRate  RiskLevel
# 0   25         130           80  15.0      98.0         86  high risk
# 1   35         140           90  13.0      98.0         70  high risk
# 2   29          90           70   8.0     100.0         80  high risk
# 3   30         140           85   7.0      98.0         70  high risk
# 4   35         120           60   6.1      98.0         76   low risk

# %%
df.tail()
# Out:
#       Age  SystolicBP  DiastolicBP    BS  BodyTemp  HeartRate  RiskLevel
# 1009   22         120           60  15.0      98.0         80  high risk
# 1010   55         120           90  18.0      98.0         60  high risk
# 1011   35          85           60  19.0      98.0         86  high risk
# 1012   43         120           90  18.0      98.0         70  high risk
# 1013   32         120           65   6.0     101.0         76   mid risk

# %%
df.isnull().sum()
# Out:
# Age            0
# SystolicBP     0
# DiastolicBP    0
# BS             0
# BodyTemp       0
# HeartRate      0
# RiskLevel      0
# dtype: int64

# %%
df['Age'].unique()
# Out:
# array([25, 35, 29, 30, 23, 32, 42, 19, 20, 48, 15, 50, 10, 40, 21, 18, 16,
#        22, 49, 28, 12, 60, 55, 45, 31, 17, 26, 54, 44, 33, 13, 34, 38, 39,
#        63, 14, 37, 51, 62, 43, 65, 66, 56, 70, 27, 36, 59, 24, 41, 46])

# %%
df['RiskLevel'].value_counts()
# Out:
# RiskLevel
# low risk     406
# mid risk     336
# high risk    272
# Name: count, dtype: int64

# %%
df['HeartRate'].value_counts()
# Out:
# HeartRate
# 70    271
# 76    131
# 80    117
# 77     96
# 66     87
# 60     74
# 88     59
# 86     55
# 78     46
# 90     19
# 82     19
# 75     19
# 67     12
# 65      5
# 68      2
# 7       2
# Name: count, dtype: int64

# %%
sns.countplot(x= 'RiskLevel', data =df)
plt.title('Risk Level Count')
plt.show()

# %%
sns.barplot(x='RiskLevel', y='Age', data=df)
plt.title('Risk Level vs Age')
plt.show()

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
df1 = df.copy()

# %%
sns.pairplot(df1, hue='RiskLevel')
plt.show()

# %%
sns.boxplot(x='RiskLevel', y='Age', data=df)
plt.title('Risk Level vs Age')
plt.show()

# %%
plt.pie(df['RiskLevel'].value_counts(), labels=df['RiskLevel'].unique(), autopct='%1.1f%%')
plt.title('Risk Level Distribution')
plt.show()

# %%
sns.histplot(data=df, x='Age', kde=True)
plt.title('Age Distribution')
plt.show()

# %%
df.groupby('RiskLevel')['Age'].mean()
# Out:
# RiskLevel
# high risk    36.216912
# low risk     26.869458
# mid risk     28.363095
# Name: Age, dtype: float64

# %%
df.groupby('RiskLevel')['SystolicBP'].mean()
# Out:
# RiskLevel
# high risk    124.194853
# low risk     105.866995
# mid risk     113.154762
# Name: SystolicBP, dtype: float64

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='RiskLevel', y='SystolicBP', data=df)
plt.title('Risk Level vs Systolic BP')
plt.show()

# %%
numeric_columns = df.select_dtypes(include=['number'])
df_normalized = (numeric_columns - numeric_columns.min()) / (numeric_columns.max() - numeric_columns.min())
df_normalized
# Out:
#            Age  SystolicBP  DiastolicBP        BS  BodyTemp  HeartRate
# 0     0.250000    0.666667     0.607843  0.692308       0.0   0.951807
# 1     0.416667    0.777778     0.803922  0.538462       0.0   0.759036
# 2     0.316667    0.222222     0.411765  0.153846       0.4   0.879518
# 3     0.333333    0.777778     0.705882  0.076923       0.0   0.759036
# 4     0.416667    0.555556     0.215686  0.007692       0.0   0.831325
# ...        ...         ...          ...       ...       ...        ...
# 1009  0.200000    0.555556     0.215686  0.692308       0.0   0.879518
# 1010  0.750000    0.555556     0.803922  0.923077       0.0   0.638554
# 1011  0.416667    0.166667     0.215686  1.000000       0.0   0.951807
# 1012  0.550000    0.555556     0.803922  0.923077       0.0   0.759036
# 1013  0.366667    0.555556     0.313725  0.000000       0.6   0.831325
#
# [1014 rows x 6 columns]

# %%
for col in numeric_columns:
    df[col].hist()
    plt.title(col)
    plt.show()

# %%
print(pd.crosstab(df['RiskLevel'], df['Age']))
# Out:
# Age        10  12  13  14  15  16  17  18  19  20  ...  54  55  56  59  60  \
# RiskLevel                                          ...
# high risk   0   7   3   3   0   0  24   0   2   0  ...   9  17   1   0   7
# low risk    2  15   2   0  56  10  18   8  28  11  ...   0  12   0   2  13
# mid risk    2  13   7   0   4   6  21  11  37  11  ...   3   8   0   0  14
#
# Age        62  63  65  66  70
# RiskLevel
# high risk   0   2   1   0   0
# low risk    1   0   2   1   1
# mid risk    0   0   0   0   0
#
# [3 rows x 50 columns]

# %%
table = pd.crosstab(df['RiskLevel'], df['HeartRate'])
table.plot(kind='bar', stacked=True)
plt.title('Risk Level vs HeartRate')
plt.xlabel('HeartRate')
plt.ylabel('Count')
plt.show()

# %%
plt.scatter(df['Age'], df['SystolicBP'])
plt.title('Age vs Systolic BP')
plt.xlabel('Age')
plt.ylabel('Systolic BP')
plt.show()

# %%
plt.scatter(df['Age'], df['DiastolicBP'])
plt.title('Age vs Diastolic BP')
plt.xlabel('Age')
plt.ylabel('Diastolic BP')
plt.show()

# %%
plt.scatter(df['SystolicBP'], df['DiastolicBP'])
plt.title('Systolic BP vs Diastolic BP')
plt.xlabel('Systolic BP')
plt.ylabel('Diastolic BP')
plt.show()

# %%
plt.scatter(df['Age'], df['BodyTemp'])
plt.title('Age vs Body Temperature')
plt.xlabel('Age')
plt.ylabel('Body Temperature')
plt.show()

# %%
plt.hist(df['Age'], bins=10, edgecolor='k')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['SystolicBP'], bins=10, edgecolor='k')
plt.title('Systolic BP Distribution')
plt.xlabel('Systolic BP')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['DiastolicBP'], bins=10, edgecolor='k')
plt.title('Diastolic BP Distribution')
plt.xlabel('Diastolic BP')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['BodyTemp'], bins=10, edgecolor='k')
plt.title('Body Temperature Distribution')
plt.xlabel('Body Temperature')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['HeartRate'], bins=10, edgecolor='k')
plt.title('Heart Rate Distribution')
plt.xlabel('Heart Rate')
plt.ylabel('Frequency')
plt.show()

# %%
df.groupby('RiskLevel')['Age'].mean()
# Out:
# RiskLevel
# high risk    36.216912
# low risk     26.869458
# mid risk     28.363095
# Name: Age, dtype: float64

# %%
df.sort_values(by='Age', ascending=False)
# Out:
#      Age  SystolicBP  DiastolicBP    BS  BodyTemp  HeartRate  RiskLevel
# 338   70          85           60   6.9     102.0         70   low risk
# 326   66          85           60   6.9      98.0         86   low risk
# 339   65         120           90   6.9     103.0         76   low risk
# 435   65         130           80  15.0      98.0         86  high risk
# 322   65          90           60   6.9      98.0         70   low risk
# ..   ...         ...          ...   ...       ...        ...        ...
# 171   12          90           60   7.9     102.0         66  high risk
# 250   10          85           65   6.9      98.0         70   low risk
# 670   10         100           50   6.0      99.0         70   mid risk
# 19    10          70           50   6.9      98.0         70   low risk
# 849   10         100           50   6.0      99.0         70   mid risk
#
# [1014 rows x 7 columns]

# %%
high_risk_df = df[df['RiskLevel'] == 'high risk']
print(high_risk_df)
# Out:
#       Age  SystolicBP  DiastolicBP     BS  BodyTemp  HeartRate  RiskLevel
# 0      25         130           80  15.00      98.0         86  high risk
# 1      35         140           90  13.00      98.0         70  high risk
# 2      29          90           70   8.00     100.0         80  high risk
# 3      30         140           85   7.00      98.0         70  high risk
# 5      23         140           80   7.01      98.0         70  high risk
# ...   ...         ...          ...    ...       ...        ...        ...
# 1008   48         120           80  11.00      98.0         88  high risk
# 1009   22         120           60  15.00      98.0         80  high risk
# 1010   55         120           90  18.00      98.0         60  high risk
# 1011   35          85           60  19.00      98.0         86  high risk
# 1012   43         120           90  18.00      98.0         70  high risk
#
# [272 rows x 7 columns]

# %%
critical= df[(df['RiskLevel'] == 'high risk') & (df['HeartRate'] > 80) & (df['BodyTemp'] > 98)]
print(critical)
# Out:
#       Age  SystolicBP  DiastolicBP    BS  BodyTemp  HeartRate  RiskLevel
# 7      35          85           60  11.0     102.0         86  high risk
# 105    34          85           60  11.0     102.0         86  high risk
# 111    38         135           60   7.9     101.0         86  high risk
# 192    28          83           60   8.0     101.0         86  high risk
# 199    17          85           60   9.0     102.0         86  high risk
# 295    17          85           60   6.3     102.0         86  high risk
# 390    17          85           69   7.8     102.0         86  high risk
# 442    35          85           60  11.0     102.0         86  high risk
# 458    34          85           60  11.0     102.0         86  high risk
# 486    38         135           60   7.9     101.0         86  high risk
# 613    27         135           60   7.5     101.0         86  high risk
# 620    17          85           60   7.5     101.0         86  high risk
# ...

# %%
t= df.rename(columns={'RiskLevel': 'Risk_Level'}, inplace=True)
t

# %%
sns.pairplot(df, hue='Age')
plt.show()

# %%
df.describe()
# Out:
#                Age   SystolicBP  DiastolicBP           BS     BodyTemp  \
# count  1014.000000  1014.000000  1014.000000  1014.000000  1014.000000
# mean     29.871795   113.198225    76.460552     8.725986    98.665089
# std      13.474386    18.403913    13.885796     3.293532     1.371384
# min      10.000000    70.000000    49.000000     6.000000    98.000000
# 25%      19.000000   100.000000    65.000000     6.900000    98.000000
# 50%      26.000000   120.000000    80.000000     7.500000    98.000000
# 75%      39.000000   120.000000    90.000000     8.000000    98.000000
# max      70.000000   160.000000   100.000000    19.000000   103.000000
#
#          HeartRate
# count  1014.000000
# mean     74.301775
# std       8.088702
# min       7.000000
# 25%      70.000000
# 50%      76.000000
# 75%      80.000000
# max      90.000000

# %%
Q1 = 19.0
Q3 = 26.0
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df_filtered = df[(df['Age'] >= lower_bound) & (df['Age'] <= upper_bound)]
df_filtered
# Out:
#       Age  SystolicBP  DiastolicBP    BS  BodyTemp  HeartRate Risk_Level
# 0      25         130           80  15.0      98.0         86  high risk
# 1      35         140           90  13.0      98.0         70  high risk
# 2      29          90           70   8.0     100.0         80  high risk
# 3      30         140           85   7.0      98.0         70  high risk
# 4      35         120           60   6.1      98.0         76   low risk
# ...   ...         ...          ...   ...       ...        ...        ...
# 1005   17          90           65   7.7     103.0         67  high risk
# 1006   17          85           60   6.3     102.0         86  high risk
# 1009   22         120           60  15.0      98.0         80  high risk
# 1011   35          85           60  19.0      98.0         86  high risk
# 1013   32         120           65   6.0     101.0         76   mid risk
#
# [750 rows x 7 columns]
