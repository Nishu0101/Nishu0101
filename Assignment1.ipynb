# %% [markdown]
# <a href="https://colab.research.google.com/github/Nishu0101/Nishu0101/blob/main/Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#WAP to display the last digit of a number (Don’t use indexing for this)
num=int(input("Enter a number"))
last_digit=num%10
print(last_digit)
# Out:
# Enter a number9
# 9

# %%
#WAP to check if a single character is a vowel or not.
alphabet=str(input("Enter a character:"))
if alphabet=='a' or alphabet=='e' or alphabet=='i' or alphabet=='o' or alphabet=='u':
    print("Vowel")
else:
    print("Not a vowel")
# Out:
# Enter a character:kl
# Not a vowel

# %%
#WAP to check if a number is even or odd where the number is taken as input
num=int(input("Enter a numner"))
if num%2==0:
    print("Even")
else:
    print("Odd")
# Out:
# Enter a numner89
# Odd

# %%
#WAP to check if the 3rd last character of a string is a vowel or not
alphabet=str(input("Enter a character:"))
last_3rd=alphabet[-3]
if last_3rd=='a' or last_3rd=='e' or last_3rd=='i' or last_3rd=='o' or last_3rd=='u':
    print("Vowel")
else:
    print("Not a vowel")
# Out:
# Enter a character:hkk
# Not a vowel

# %%
#Check if the first and last number of a list is same or not. Take a pre-defined list in the code itself
l=[24,56,78,9,80,24]
first_number=l[0]
last_number=l[-1]
if(first_number==last_number):
    print("Same")
else:
    print("Not same")
# Out:
# Same

# %%
#Calculate income tax for the input income by adhering to the Indian rules
income=int(input("Enter your income"))
if income <700000:
  print("no tax")
else:
  tax=income*0.05
  print(tax)
# Out:
# Enter your income900000
# 45000.0

# %%
#Write a Python program to check whether a string starts with vowel or not
alphabet=str(input("Enter a word:"))
if alphabet[0]=='a' or alphabet[0]=='e' or alphabet[0]=='i' or alphabet[0]=='o' or alphabet[0]=='u':
    print("starts with vowel")
else:
  print("Not starts with vowel")
# Out:
# Enter a word:jjk
# Not starts with vowel

# %%
#WAP to calculate percentage of a student through 5 subjects. Take marks as input from the user,Using percentage print which grade the student has scored
sub1=int(input("Enter marks of 1st sub"))
sub2=int(input("Enter marks of 2nd sub"))
sub3=int(input("Enter marks of 3rd sub"))
sub4=int(input("Enter marks of 4th sub"))
sub5=int(input("Enter marks of 5th sub"))
percentage=((sub1+sub2+sub3+sub4+sub5)/5)%100
print("Percentage =",percentage)
if percentage>=90:
  print("Grade A")
elif percentage>=80:
  print("Grade B")
elif percentage>=70:
  print("Grade C")
elif percentage>=60:
  print("Grade D")
# Out:
# Enter marks of 1st sub67
# Enter marks of 2nd sub89
# Enter marks of 3rd sub90
# Enter marks of 4th sub90
# Enter marks of 5th sub99
# Percentage = 87.0
# Grade B

# %%
#WAP to convert a celsius value to fahrenheit. Take celsius value as input
Celsius=int(input("Enter temperature in Celcius"))
Fahrenheit = (Celsius*9/5) + 32.
print(Fahrenheit,"°F")
# Out:
# Enter temperature in Celcius89
# 192.2 °F

# %%
#WAP to calculate the surface area of a triangle. Take the length of sides as input
s1=int(input("Enter 1st length "))
s2=int(input("Enter 1st length "))
s3=int(input("Enter 1st length "))
s=(s1+s2+s3)/2
area=(s*(s-s1)*(s-s2)*(s-s3))**0.5
print("Area of triangle =",area)
# Out:
# Enter 1st length 56
# Enter 1st length 9
# Enter 1st length 9
# Area of triangle = (4.54586516444793e-14+742.3961206795198j)

# %%
#WAP to print the day based on the number input.For example: if input = 1, output = (Monday)
num=int(input("Enter a number"))
if num==1:
  print("Monday")
elif num==2:
  print("Tuesday")
elif num==3:
  print("Wednesday")
elif num==4:
  print("Thursday")
elif num==5:
  print("Friday")
elif num==6:
  print("Saturday")
elif num==7:
  print("Sunday")
else:
  print("Invalid input")
# Out:
# Enter a number7
# Sunday

# %%
#WAP to check whether a person is eligible to vote or not based on their age
age=int(input("Enter your age"))
if age>=18:
  print("Eligible to vote")
else:
  print("Not eligible to vote")
# Out:
# Enter your age45
# Eligible to vote

# %%
#WAP to calculate the count of elements in a string
string=str(input("Enter a string"))
print(len(string))
# Out:
# Enter a stringnishu
# 5

# %%
#WAP to check using the sides of a triangle to tell if it is equilateral triangle or not
s1=int(input("Enter 1st length "))
s2=int(input("Enter 1st length "))
s3=int(input("Enter 1st length "))
if s1==s2==s3:
  print("Equilateral triangle")
else:
  print("Not equilateral triangle")
# Out:
# Enter 1st length 4
# Enter 1st length 6
# Enter 1st length 4
# Not equilateral triangle

# %%
#WAP to check if the 2nd last digit of numerical input from the user is divisible by 3 or not
num=int(input("Enter a number"))
last_digit=num%10
second_last_digit=(num//10)%10
if second_last_digit%3==0:
  print("Divisible by 3")
else:
  print("Not divisible by 3")
# Out:
# Enter a number698
# Divisible by 3

# %%
#Write a Python program that takes two numbers as input from the user and prints the larger of the two numbers
num1=int(input("Enter a number"))
num2=int(input("Enter a number"))
if num1>num2:
  print(num1,"is greater")
else:
  print(num2,"is greater")
# Out:
# Enter a number45
# Enter a number67
# 67 is greater
